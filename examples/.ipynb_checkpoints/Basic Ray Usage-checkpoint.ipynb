# %% [markdown]
# ## Ray Config

# %%
import ray
from ray import tune

# %%
import time

@ray.remote
def func():
    time.sleep(5)
    return 1

# %%
ray.shutdown()

# %%
ray.init(num_cpus=4) # one raylet (local machine) with 6 cpus.
# Out:
# 2019-08-28 22:05:34,082	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-28_22-05-34_074358_17/logs.
# 2019-08-28 22:05:34,211	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:53827 to respond...
# 2019-08-28 22:05:34,342	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:20545 to respond...
# 2019-08-28 22:05:34,346	INFO services.py:809 -- Starting Redis shard with 0.83 GB max memory.
# 2019-08-28 22:05:34,396	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-28_22-05-34_074358_17/logs.
# 2019-08-28 22:05:34,402	INFO services.py:1475 -- Starting the Plasma object store with 1.24 GB memory using /dev/shm.
# {'node_ip_address': '172.17.0.2',
#  'redis_address': '172.17.0.2:53827',
#  'object_store_address': '/tmp/ray/session_2019-08-28_22-05-34_074358_17/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-08-28_22-05-34_074358_17/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2019-08-28_22-05-34_074358_17'}

# %% [markdown]
# ## Basic Examples

# %%
# %%time

# Execute function on Ray and get result.
o_id = func.remote()
ray.get(o_id)
# Out:
# CPU times: user 190 ms, sys: 170 ms, total: 360 ms
# Wall time: 5.35 s
# 1

# %%
# %%time

# Run 6 instances in parallel, one per core. Serial time = 30 seconds. Parallel ~ 5.
ray.get([func.remote() for _ in range(4)])
# Out:
# CPU times: user 180 ms, sys: 140 ms, total: 320 ms
# Wall time: 5.41 s
# [1, 1, 1, 1]

# %% [markdown]
# ## Experiment Runner

# %%
class ExampleExperiment(tune.Trainable):
    def _setup(self, config):
        self.config = config

    def _train(self):
        config = self.config
        some_metric = config["alpha"] + config["beta"] + config["list_value"][0]
        result_dict = {"some_metric": some_metric}
        
        if self.iteration == 5:
            result_dict["done"] = tune.result.DONE
            
        return result_dict

# %%
analysis = tune.run(
     ExampleExperiment,
     name="example-experiment",
     num_samples=5,
     config={
         "alpha": tune.sample_from(lambda spec: np.random.uniform(1)),
         "beta": tune.sample_from(lambda spec: spec.config.alpha * np.random.normal()),
         "list_value": [
             tune.grid_search([8, 12]),
             tune.grid_search([16, 64]),
         ]
     }
 )
# Out:
# 2019-08-28 22:02:44,074	INFO trial_runner.py:176 -- Starting a new experiment.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/0 GPUs
# Memory usage on this node: 1.3/4.1 GB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/4 CPUs, 0/0 GPUs
# Memory usage on this node: 1.3/4.1 GB
# Result logdir: /home/jovyan/ray_results/example-experiment
# Number of trials: 20 ({'RUNNING': 1, 'PENDING': 19})
# PENDING trials:
#  - ExampleExperiment_1_alpha=1.0,beta=2.5322,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_2_alpha=1.0,beta=-0.251,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_3_alpha=1.0,beta=-1.9911,list_value_0=12,list_value_1=64:	PENDING
#  - ExampleExperiment_4_alpha=1.0,beta=0.016279,list_value_0=8,list_value_1=16:	PENDING
#  - ExampleExperiment_5_alpha=1.0,beta=-0.33695,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_6_alpha=1.0,beta=0.044486,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_7_alpha=1.0,beta=-0.81658,list_value_0=12,list_value_1=64:	PENDING
#  - ExampleExperiment_8_alpha=1.0,beta=-0.38954,list_value_0=8,list_value_1=16:	PENDING
#  - ExampleExperiment_9_alpha=1.0,beta=-0.40787,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_10_alpha=1.0,beta=-0.59058,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_11_alpha=1.0,beta=-0.021032,list_value_0=12,list_value_1=64:	PENDING
#  - ExampleExperiment_12_alpha=1.0,beta=0.26713,list_value_0=8,list_value_1=16:	PENDING
#  - ExampleExperiment_13_alpha=1.0,beta=-0.95294,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_14_alpha=1.0,beta=0.10117,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_15_alpha=1.0,beta=0.90247,list_value_0=12,list_value_1=64:	PENDING
#  - ExampleExperiment_16_alpha=1.0,beta=1.9151,list_value_0=8,list_value_1=16:	PENDING
#  - ExampleExperiment_17_alpha=1.0,beta=-0.17878,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_18_alpha=1.0,beta=1.0675,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_19_alpha=1.0,beta=0.087757,list_value_0=12,list_value_1=64:	PENDING
# RUNNING trials:
#  - ExampleExperiment_0_alpha=1.0,beta=-0.42274,list_value_0=8,list_value_1=16:	RUNNING
#
# Result for ExampleExperiment_0_alpha=1.0,beta=-0.42274,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-44
#   done: false
#   experiment_id: 87be90942c2144bcad63a8622925af74
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 617
#   some_metric: 8.577264533965716
#   time_since_restore: 1.4066696166992188e-05
#   time_this_iter_s: 1.4066696166992188e-05
#   time_total_s: 1.4066696166992188e-05
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fe9a6e6
#
# Result for ExampleExperiment_0_alpha=1.0,beta=-0.42274,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-44
#   done: true
#   experiment_id: 87be90942c2144bcad63a8622925af74
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 617
#   some_metric: 8.577264533965716
#   time_since_restore: 9.632110595703125e-05
#   time_this_iter_s: 2.193450927734375e-05
#   time_total_s: 9.632110595703125e-05
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fe9a6e6
#
# Result for ExampleExperiment_1_alpha=1.0,beta=2.5322,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-44
#   done: false
#   experiment_id: e6f330d571fa4973934069ed12c168ea
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 620
#   some_metric: 15.532151610979696
#   time_since_restore: 8.821487426757812e-06
#   time_this_iter_s: 8.821487426757812e-06
#   time_total_s: 8.821487426757812e-06
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fe9d6a2
#
# Result for ExampleExperiment_2_alpha=1.0,beta=-0.251,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-44
#   done: false
#   experiment_id: a59f5888fb7b4b5baeeb1fb33c2fce43
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 618
#   some_metric: 8.748997266933205
#   time_since_restore: 0.0002484321594238281
#   time_this_iter_s: 0.0002484321594238281
#   time_total_s: 0.0002484321594238281
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fea0a6e
#
# Result for ExampleExperiment_1_alpha=1.0,beta=2.5322,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-44
#   done: true
#   experiment_id: e6f330d571fa4973934069ed12c168ea
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 620
#   some_metric: 15.532151610979696
#   time_since_restore: 0.00010800361633300781
#   time_this_iter_s: 2.7179718017578125e-05
#   time_total_s: 0.00010800361633300781
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fe9d6a2
#
# Result for ExampleExperiment_3_alpha=1.0,beta=-1.9911,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-44
#   done: false
#   experiment_id: 8912e95790324c27842cb9163d450a70
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 619
#   some_metric: 11.008941199503436
#   time_since_restore: 1.52587890625e-05
#   time_this_iter_s: 1.52587890625e-05
#   time_total_s: 1.52587890625e-05
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fea35de
#
# Result for ExampleExperiment_2_alpha=1.0,beta=-0.251,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-44
#   done: true
#   experiment_id: a59f5888fb7b4b5baeeb1fb33c2fce43
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 618
#   some_metric: 8.748997266933205
#   time_since_restore: 0.0003554821014404297
#   time_this_iter_s: 2.9325485229492188e-05
#   time_total_s: 0.0003554821014404297
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fea0a6e
#
# Result for ExampleExperiment_3_alpha=1.0,beta=-1.9911,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-44
#   done: true
#   experiment_id: 8912e95790324c27842cb9163d450a70
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 619
#   some_metric: 11.008941199503436
#   time_since_restore: 0.0002300739288330078
#   time_this_iter_s: 2.2172927856445312e-05
#   time_total_s: 0.0002300739288330078
#   timestamp: 1567029764
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fea35de
#
# Result for ExampleExperiment_5_alpha=1.0,beta=-0.33695,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-46
#   done: false
#   experiment_id: 6b69eff8990d4e9dab580e5e9a79b1d4
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 659
#   some_metric: 12.66305369751521
#   time_since_restore: 1.9311904907226562e-05
#   time_this_iter_s: 1.9311904907226562e-05
#   time_total_s: 1.9311904907226562e-05
#   timestamp: 1567029766
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8feadafc
#
# Result for ExampleExperiment_5_alpha=1.0,beta=-0.33695,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-46
#   done: true
#   experiment_id: 6b69eff8990d4e9dab580e5e9a79b1d4
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 659
#   some_metric: 12.66305369751521
#   time_since_restore: 0.00012302398681640625
#   time_this_iter_s: 2.47955322265625e-05
#   time_total_s: 0.00012302398681640625
#   timestamp: 1567029766
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8feadafc
#
# Result for ExampleExperiment_4_alpha=1.0,beta=0.016279,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-46
#   done: false
#   experiment_id: 48712607b56d4b73af1fcaaa1dfe835e
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 660
#   some_metric: 9.01627858151397
#   time_since_restore: 1.6927719116210938e-05
#   time_this_iter_s: 1.6927719116210938e-05
#   time_total_s: 1.6927719116210938e-05
#   timestamp: 1567029766
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fea72b0
#
# Result for ExampleExperiment_4_alpha=1.0,beta=0.016279,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-47
#   done: true
#   experiment_id: 48712607b56d4b73af1fcaaa1dfe835e
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 660
#   some_metric: 9.01627858151397
#   time_since_restore: 9.822845458984375e-05
#   time_this_iter_s: 2.288818359375e-05
#   time_total_s: 9.822845458984375e-05
#   timestamp: 1567029767
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fea72b0
#
# Result for ExampleExperiment_7_alpha=1.0,beta=-0.81658,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-47
#   done: false
#   experiment_id: e69e5e2816fd4363a2661755d9701a1e
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 661
#   some_metric: 12.183415997203118
#   time_since_restore: 1.9550323486328125e-05
#   time_this_iter_s: 1.9550323486328125e-05
#   time_total_s: 1.9550323486328125e-05
#   timestamp: 1567029767
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8feb6828
# Result for ExampleExperiment_7_alpha=1.0,beta=-0.81658,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-47
#   done: true
#   experiment_id: e69e5e2816fd4363a2661755d9701a1e
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 661
#   some_metric: 12.183415997203118
#   time_since_restore: 0.00012159347534179688
#   time_this_iter_s: 2.2172927856445312e-05
#   time_total_s: 0.00012159347534179688
#   timestamp: 1567029767
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8feb6828
#
# Result for ExampleExperiment_6_alpha=1.0,beta=0.044486,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-47
#   done: false
#   experiment_id: ace39ab89e8749be8ee2a4f6a58fa3a4
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 658
#   some_metric: 9.044485527812212
#   time_since_restore: 1.621246337890625e-05
#   time_this_iter_s: 1.621246337890625e-05
#   time_total_s: 1.621246337890625e-05
#   timestamp: 1567029767
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8feb37cc
#
# Result for ExampleExperiment_6_alpha=1.0,beta=0.044486,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-47
#   done: true
#   experiment_id: ace39ab89e8749be8ee2a4f6a58fa3a4
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 658
#   some_metric: 9.044485527812212
#   time_since_restore: 0.00012350082397460938
#   time_this_iter_s: 2.1696090698242188e-05
#   time_total_s: 0.00012350082397460938
#   timestamp: 1567029767
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8feb37cc
#
# Result for ExampleExperiment_9_alpha=1.0,beta=-0.40787,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-48
#   done: false
#   experiment_id: e635084a71c044a29ca6eed90221728d
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 688
#   some_metric: 12.592132605882917
#   time_since_restore: 1.5497207641601562e-05
#   time_this_iter_s: 1.5497207641601562e-05
#   time_total_s: 1.5497207641601562e-05
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8febf0ae
#
# Result for ExampleExperiment_8_alpha=1.0,beta=-0.38954,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-48
#   done: false
#   experiment_id: 59ddb5e642c14917b0ff7f64baec93b2
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 679
#   some_metric: 8.610460089389974
#   time_since_restore: 1.8596649169921875e-05
#   time_this_iter_s: 1.8596649169921875e-05
#   time_total_s: 1.8596649169921875e-05
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8febb256
#
# Result for ExampleExperiment_9_alpha=1.0,beta=-0.40787,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-48
#   done: true
#   experiment_id: e635084a71c044a29ca6eed90221728d
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 688
#   some_metric: 12.592132605882917
#   time_since_restore: 0.00011396408081054688
#   time_this_iter_s: 1.0967254638671875e-05
#   time_total_s: 0.00011396408081054688
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8febf0ae
#
# Result for ExampleExperiment_8_alpha=1.0,beta=-0.38954,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-48
#   done: true
#   experiment_id: 59ddb5e642c14917b0ff7f64baec93b2
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 679
#   some_metric: 8.610460089389974
#   time_since_restore: 0.00011897087097167969
#   time_this_iter_s: 2.3603439331054688e-05
#   time_total_s: 0.00011897087097167969
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8febb256
#
# Result for ExampleExperiment_10_alpha=1.0,beta=-0.59058,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-48
#   done: false
#   experiment_id: f4b3ca15e04340afb1c5f6e8c8c14bed
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 685
#   some_metric: 8.409418556472788
#   time_since_restore: 3.0994415283203125e-05
#   time_this_iter_s: 3.0994415283203125e-05
#   time_total_s: 3.0994415283203125e-05
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fec2dbc
#
# Result for ExampleExperiment_10_alpha=1.0,beta=-0.59058,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-48
#   done: true
#   experiment_id: f4b3ca15e04340afb1c5f6e8c8c14bed
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 685
#   some_metric: 8.409418556472788
#   time_since_restore: 0.00013446807861328125
#   time_this_iter_s: 2.8371810913085938e-05
#   time_total_s: 0.00013446807861328125
#   timestamp: 1567029768
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fec2dbc
#
# Result for ExampleExperiment_11_alpha=1.0,beta=-0.021032,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-49
#   done: false
#   experiment_id: 5b89c22d421b447c8e6a3a2130ab800b
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 711
#   some_metric: 12.978967559670934
#   time_since_restore: 2.5033950805664062e-05
#   time_this_iter_s: 2.5033950805664062e-05
#   time_total_s: 2.5033950805664062e-05
#   timestamp: 1567029769
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fec5c56
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 4/4 CPUs, 0/0 GPUs
# Memory usage on this node: 1.2/4.1 GB
# Result logdir: /home/jovyan/ray_results/example-experiment
# Number of trials: 20 ({'TERMINATED': 11, 'RUNNING': 4, 'PENDING': 5})
# PENDING trials:
#  - ExampleExperiment_15_alpha=1.0,beta=0.90247,list_value_0=12,list_value_1=64:	PENDING
#  - ExampleExperiment_16_alpha=1.0,beta=1.9151,list_value_0=8,list_value_1=16:	PENDING
#  - ExampleExperiment_17_alpha=1.0,beta=-0.17878,list_value_0=12,list_value_1=16:	PENDING
#  - ExampleExperiment_18_alpha=1.0,beta=1.0675,list_value_0=8,list_value_1=64:	PENDING
#  - ExampleExperiment_19_alpha=1.0,beta=0.087757,list_value_0=12,list_value_1=64:	PENDING
# RUNNING trials:
#  - ExampleExperiment_11_alpha=1.0,beta=-0.021032,list_value_0=12,list_value_1=64:	RUNNING, [1 CPUs, 0 GPUs], [pid=711], 0 s, 1 iter
#  - ExampleExperiment_12_alpha=1.0,beta=0.26713,list_value_0=8,list_value_1=16:	RUNNING
#  - ExampleExperiment_13_alpha=1.0,beta=-0.95294,list_value_0=12,list_value_1=16:	RUNNING
#  - ExampleExperiment_14_alpha=1.0,beta=0.10117,list_value_0=8,list_value_1=64:	RUNNING
# TERMINATED trials:
#  - ExampleExperiment_0_alpha=1.0,beta=-0.42274,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=617], 0 s, 6 iter
#  - ExampleExperiment_1_alpha=1.0,beta=2.5322,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=620], 0 s, 6 iter
#  - ExampleExperiment_2_alpha=1.0,beta=-0.251,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=618], 0 s, 6 iter
#  - ExampleExperiment_3_alpha=1.0,beta=-1.9911,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=619], 0 s, 6 iter
#  - ExampleExperiment_4_alpha=1.0,beta=0.016279,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=660], 0 s, 6 iter
#  - ExampleExperiment_5_alpha=1.0,beta=-0.33695,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=659], 0 s, 6 iter
#  - ExampleExperiment_6_alpha=1.0,beta=0.044486,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=658], 0 s, 6 iter
#  - ExampleExperiment_7_alpha=1.0,beta=-0.81658,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=661], 0 s, 6 iter
#  - ExampleExperiment_8_alpha=1.0,beta=-0.38954,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=679], 0 s, 6 iter
#  - ExampleExperiment_9_alpha=1.0,beta=-0.40787,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=688], 0 s, 6 iter
#  - ExampleExperiment_10_alpha=1.0,beta=-0.59058,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=685], 0 s, 6 iter
#
# Result for ExampleExperiment_11_alpha=1.0,beta=-0.021032,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-49
#   done: true
#   experiment_id: 5b89c22d421b447c8e6a3a2130ab800b
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 711
#   some_metric: 12.978967559670934
#   time_since_restore: 0.00014829635620117188
#   time_this_iter_s: 1.9550323486328125e-05
#   time_total_s: 0.00014829635620117188
#   timestamp: 1567029769
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fec5c56
# Result for ExampleExperiment_12_alpha=1.0,beta=0.26713,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-51
#   done: false
#   experiment_id: 3d5d554ab7d444018bbce857e67f3ac0
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 724
#   some_metric: 9.26712926503789
#   time_since_restore: 2.288818359375e-05
#   time_this_iter_s: 2.288818359375e-05
#   time_total_s: 2.288818359375e-05
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fec99a0
#
# Result for ExampleExperiment_12_alpha=1.0,beta=0.26713,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-51
#   done: true
#   experiment_id: 3d5d554ab7d444018bbce857e67f3ac0
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 724
#   some_metric: 9.26712926503789
#   time_since_restore: 0.00012493133544921875
#   time_this_iter_s: 2.3365020751953125e-05
#   time_total_s: 0.00012493133544921875
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fec99a0
#
# Result for ExampleExperiment_13_alpha=1.0,beta=-0.95294,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-51
#   done: false
#   experiment_id: 4f5557ca89dd4234bb55cad015b08520
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 721
#   some_metric: 12.0470580120225
#   time_since_restore: 2.2172927856445312e-05
#   time_this_iter_s: 2.2172927856445312e-05
#   time_total_s: 2.2172927856445312e-05
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fecc3d0
#
# Result for ExampleExperiment_13_alpha=1.0,beta=-0.95294,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-51
#   done: true
#   experiment_id: 4f5557ca89dd4234bb55cad015b08520
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 721
#   some_metric: 12.0470580120225
#   time_since_restore: 0.000240325927734375
#   time_this_iter_s: 0.0001246929168701172
#   time_total_s: 0.000240325927734375
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fecc3d0
#
# Result for ExampleExperiment_14_alpha=1.0,beta=0.10117,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-51
#   done: false
#   experiment_id: d810266d40b344fda80d9d490f91ecaa
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 722
#   some_metric: 9.101165434480746
#   time_since_restore: 2.09808349609375e-05
#   time_this_iter_s: 2.09808349609375e-05
#   time_total_s: 2.09808349609375e-05
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fece932
#
# Result for ExampleExperiment_15_alpha=1.0,beta=0.90247,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-51
#   done: false
#   experiment_id: f6c08e22956d4812a8418c462499214b
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 723
#   some_metric: 13.902466863160234
#   time_since_restore: 2.002716064453125e-05
#   time_this_iter_s: 2.002716064453125e-05
#   time_total_s: 2.002716064453125e-05
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fed15e2
#
# Result for ExampleExperiment_14_alpha=1.0,beta=0.10117,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-51
#   done: true
#   experiment_id: d810266d40b344fda80d9d490f91ecaa
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 722
#   some_metric: 9.101165434480746
#   time_since_restore: 0.000125885009765625
#   time_this_iter_s: 2.574920654296875e-05
#   time_total_s: 0.000125885009765625
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fece932
#
# Result for ExampleExperiment_15_alpha=1.0,beta=0.90247,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-51
#   done: true
#   experiment_id: f6c08e22956d4812a8418c462499214b
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 723
#   some_metric: 13.902466863160234
#   time_since_restore: 0.000141143798828125
#   time_this_iter_s: 1.8835067749023438e-05
#   time_total_s: 0.000141143798828125
#   timestamp: 1567029771
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fed15e2
#
# Result for ExampleExperiment_16_alpha=1.0,beta=1.9151,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-52
#   done: false
#   experiment_id: 21496ca0902f4b49a73ce7c53ac4f5f4
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 755
#   some_metric: 10.91514509080493
#   time_since_restore: 2.2172927856445312e-05
#   time_this_iter_s: 2.2172927856445312e-05
#   time_total_s: 2.2172927856445312e-05
#   timestamp: 1567029772
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fed4972
#
# Result for ExampleExperiment_16_alpha=1.0,beta=1.9151,list_value_0=8,list_value_1=16:
#   date: 2019-08-28_22-02-52
#   done: true
#   experiment_id: 21496ca0902f4b49a73ce7c53ac4f5f4
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 755
#   some_metric: 10.91514509080493
#   time_since_restore: 0.00016760826110839844
#   time_this_iter_s: 4.1961669921875e-05
#   time_total_s: 0.00016760826110839844
#   timestamp: 1567029772
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fed4972
#
# Result for ExampleExperiment_17_alpha=1.0,beta=-0.17878,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-53
#   done: false
#   experiment_id: c429a7898d604d069d3a6817f2075d3c
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 745
#   some_metric: 12.8212244381503
#   time_since_restore: 2.2649765014648438e-05
#   time_this_iter_s: 2.2649765014648438e-05
#   time_total_s: 2.2649765014648438e-05
#   timestamp: 1567029773
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fed730c
#
# Result for ExampleExperiment_18_alpha=1.0,beta=1.0675,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-53
#   done: false
#   experiment_id: 3b9cd4f254394ff7af9f6d34ed4afe31
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 744
#   some_metric: 10.067463894169958
#   time_since_restore: 2.193450927734375e-05
#   time_this_iter_s: 2.193450927734375e-05
#   time_total_s: 2.193450927734375e-05
#   timestamp: 1567029773
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8fed9b0c
#
# Result for ExampleExperiment_17_alpha=1.0,beta=-0.17878,list_value_0=12,list_value_1=16:
#   date: 2019-08-28_22-02-53
#   done: true
#   experiment_id: c429a7898d604d069d3a6817f2075d3c
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 745
#   some_metric: 12.8212244381503
#   time_since_restore: 0.0001270771026611328
#   time_this_iter_s: 2.002716064453125e-05
#   time_total_s: 0.0001270771026611328
#   timestamp: 1567029773
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fed730c
#
# Result for ExampleExperiment_18_alpha=1.0,beta=1.0675,list_value_0=8,list_value_1=64:
#   date: 2019-08-28_22-02-53
#   done: true
#   experiment_id: 3b9cd4f254394ff7af9f6d34ed4afe31
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 744
#   some_metric: 10.067463894169958
#   time_since_restore: 0.0001513957977294922
#   time_this_iter_s: 2.8848648071289062e-05
#   time_total_s: 0.0001513957977294922
#   timestamp: 1567029773
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8fed9b0c
#
# Result for ExampleExperiment_19_alpha=1.0,beta=0.087757,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-54
#   done: false
#   experiment_id: 3bb619e8db16447ab064140b8dab72d1
#   hostname: c3192f238ee8
#   iterations_since_restore: 1
#   node_ip: 172.17.0.2
#   pid: 775
#   some_metric: 13.08775725567052
#   time_since_restore: 1.6450881958007812e-05
#   time_this_iter_s: 1.6450881958007812e-05
#   time_total_s: 1.6450881958007812e-05
#   timestamp: 1567029774
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8feddaf4
#
# Result for ExampleExperiment_19_alpha=1.0,beta=0.087757,list_value_0=12,list_value_1=64:
#   date: 2019-08-28_22-02-54
#   done: true
#   experiment_id: 3bb619e8db16447ab064140b8dab72d1
#   hostname: c3192f238ee8
#   iterations_since_restore: 6
#   node_ip: 172.17.0.2
#   pid: 775
#   some_metric: 13.08775725567052
#   time_since_restore: 9.632110595703125e-05
#   time_this_iter_s: 1.6927719116210938e-05
#   time_total_s: 9.632110595703125e-05
#   timestamp: 1567029774
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 8feddaf4
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/4 CPUs, 0/0 GPUs
# Memory usage on this node: 1.2/4.1 GB
# Result logdir: /home/jovyan/ray_results/example-experiment
# Number of trials: 20 ({'TERMINATED': 20})
# TERMINATED trials:
#  - ExampleExperiment_0_alpha=1.0,beta=-0.42274,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=617], 0 s, 6 iter
#  - ExampleExperiment_1_alpha=1.0,beta=2.5322,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=620], 0 s, 6 iter
#  - ExampleExperiment_2_alpha=1.0,beta=-0.251,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=618], 0 s, 6 iter
#  - ExampleExperiment_3_alpha=1.0,beta=-1.9911,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=619], 0 s, 6 iter
#  - ExampleExperiment_4_alpha=1.0,beta=0.016279,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=660], 0 s, 6 iter
#  - ExampleExperiment_5_alpha=1.0,beta=-0.33695,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=659], 0 s, 6 iter
#  - ExampleExperiment_6_alpha=1.0,beta=0.044486,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=658], 0 s, 6 iter
#  - ExampleExperiment_7_alpha=1.0,beta=-0.81658,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=661], 0 s, 6 iter
#  - ExampleExperiment_8_alpha=1.0,beta=-0.38954,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=679], 0 s, 6 iter
#  - ExampleExperiment_9_alpha=1.0,beta=-0.40787,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=688], 0 s, 6 iter
#  - ExampleExperiment_10_alpha=1.0,beta=-0.59058,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=685], 0 s, 6 iter
#  - ExampleExperiment_11_alpha=1.0,beta=-0.021032,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=711], 0 s, 6 iter
#  - ExampleExperiment_12_alpha=1.0,beta=0.26713,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=724], 0 s, 6 iter
#  - ExampleExperiment_13_alpha=1.0,beta=-0.95294,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=721], 0 s, 6 iter
#  - ExampleExperiment_14_alpha=1.0,beta=0.10117,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=722], 0 s, 6 iter
#  - ExampleExperiment_15_alpha=1.0,beta=0.90247,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=723], 0 s, 6 iter
#  - ExampleExperiment_16_alpha=1.0,beta=1.9151,list_value_0=8,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=755], 0 s, 6 iter
#  - ExampleExperiment_17_alpha=1.0,beta=-0.17878,list_value_0=12,list_value_1=16:	TERMINATED, [1 CPUs, 0 GPUs], [pid=745], 0 s, 6 iter
#  - ExampleExperiment_18_alpha=1.0,beta=1.0675,list_value_0=8,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=744], 0 s, 6 iter
#  - ExampleExperiment_19_alpha=1.0,beta=0.087757,list_value_0=12,list_value_1=64:	TERMINATED, [1 CPUs, 0 GPUs], [pid=775], 0 s, 6 iter

# %%
print("Best config is", analysis.get_best_config(metric="some_metric"))
# Out:
# Best config is {'alpha': 1.0, 'beta': 2.532151610979697, 'list_value': [12, 16]}

# %%
# Get a dataframe for the last reported results of all of the trials
df = analysis.dataframe(metric="some_metric", mode="max")
df.head()
# Out:
#    some_metric   done  timesteps_total  episodes_total  training_iteration  \
# 0     8.577265  False              NaN             NaN                   1
# 1    15.532152  False              NaN             NaN                   1
# 2     8.748997  False              NaN             NaN                   1
# 3    11.008941  False              NaN             NaN                   1
# 4     9.016279  False              NaN             NaN                   1
#
#                       experiment_id                 date   timestamp  \
# 0  87be90942c2144bcad63a8622925af74  2019-08-28_22-02-44  1567029764
# 1  e6f330d571fa4973934069ed12c168ea  2019-08-28_22-02-44  1567029764
# 2  a59f5888fb7b4b5baeeb1fb33c2fce43  2019-08-28_22-02-44  1567029764
# 3  8912e95790324c27842cb9163d450a70  2019-08-28_22-02-44  1567029764
# 4  48712607b56d4b73af1fcaaa1dfe835e  2019-08-28_22-02-46  1567029766
#
#    time_this_iter_s  time_total_s  ...      hostname     node_ip  \
# 0          0.000014      0.000014  ...  c3192f238ee8  172.17.0.2
# 1          0.000009      0.000009  ...  c3192f238ee8  172.17.0.2
# 2          0.000248      0.000248  ...  c3192f238ee8  172.17.0.2
# 3          0.000015      0.000015  ...  c3192f238ee8  172.17.0.2
# 4          0.000017      0.000017  ...  c3192f238ee8  172.17.0.2
#
#   time_since_restore  timesteps_since_restore  iterations_since_restore  \
# 0           0.000014                        0                         1
# 1           0.000009                        0                         1
# 2           0.000248                        0                         1
# 3           0.000015                        0                         1
# 4           0.000017                        0                         1
#
#    trial_id config:alpha  config:beta  config:list_value  \
# 0  8fe9a6e6          1.0    -0.422735            [8, 16]
# 1  8fe9d6a2          1.0     2.532152           [12, 16]
# 2  8fea0a6e          1.0    -0.251003            [8, 64]
# 3  8fea35de          1.0    -1.991059           [12, 64]
# 4  8fea72b0          1.0     0.016279            [8, 16]
#
#                                               logdir
# 0  /home/jovyan/ray_results/example-experiment/Ex...
# 1  /home/jovyan/ray_results/example-experiment/Ex...
# 2  /home/jovyan/ray_results/example-experiment/Ex...
# 3  /home/jovyan/ray_results/example-experiment/Ex...
# 4  /home/jovyan/ray_results/example-experiment/Ex...
#
# [5 rows x 21 columns]

# %%
trials = analysis.trials # list of all trials
all_dataframes = analysis.trial_dataframes # df of iterations for each trial
